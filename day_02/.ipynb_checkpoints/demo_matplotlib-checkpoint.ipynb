# %%
import matplotlib.pyplot as plt

# 设置中文字体
import matplotlib
matplotlib.rcParams['font.sans-serif'] = ['Heiti TC']
matplotlib.rcParams['font.serif'] = ['Heiti TC']
# 设置正常显示字符
matplotlib.rcParams['axes.unicode_minus'] = False

# %% [markdown]
#  # 散点图的绘制

# %%
# 0.准备数据
x = [225.98, 247.07, 253.14, 457.85, 241.58, 301.01,  20.67, 288.64,
     163.56, 120.06, 207.83, 342.75, 147.9,  53.06, 224.72,  29.51,
     21.61, 483.21, 245.25, 399.25, 343.35]
y = [196.63, 203.88, 210.75, 372.74, 202.41, 247.61,  24.9, 239.34,
     140.32, 104.15, 176.84, 288.23, 128.79,  49.64, 191.74,  33.1,
     30.74, 400.02, 205.35, 330.64, 283.45]

# 1.创建画布
plt.figure(figsize=(20, 8), dpi=100)

# 2.绘制图像
plt.scatter(x, y)

# # 加入网格
# plt.grid()

# 3.图像显示
plt.show()

# %% [markdown]
# # 柱状图绘制

# %%
# 0.准备数据
# 电影名字
movie_name = ['雷神3：诸神黄昏', '正义联盟', '东方快车谋杀案', '寻梦环游记',
              '全球风暴', '降魔传', '追捕', '七十七天', '密战', '狂兽', '其它']

# 横坐标
x = range(len(movie_name))

# 票房数据
y = [73853, 57767, 22354, 15969, 14839, 8725, 8716, 8318, 7916, 6764, 52222]

# 1.创建画布
plt.figure(figsize=(20, 8), dpi=100)

# 2.绘制图像
plt.bar(x, y, color=['b', 'r', 'g', 'y', 'c',
        'm', 'y', 'k', 'c', 'g', 'b'], width=0.7)

# 修改x轴刻度
plt.xticks(x,movie_name)

# 修改y轴标签
plt.ylabel("票房",fontsize = 10)

# 添加标题
plt.title("电影票房收入对比图",fontsize = 20)

# 添加网格
plt.grid(True,linestyle="--",alpha = 0.8)

# 3.图像显示
plt.show()
